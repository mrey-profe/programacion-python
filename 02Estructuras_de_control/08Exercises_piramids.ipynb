# %% [markdown]
# **WARNING! Many of these exercises are advanced level**
# In these exercises, the input from the user must be checked to ensure it is a positive number greater than 0. If these conditions are not met, the program should repeatedly ask for the number until the input fulfills the requirements.
# The easiest exercises are the first four.
#
# # Exercise 1
# Create a Python program that prints a block of asterisks in multiple lines as shown below. The number of asterisks per line and the number of lines are given by the user.
# ```python
# **********
# **********
# **********
# **********
# ```
#
# # Exercise 2
# Create a Python program that prints a staircase of asterisks as shown below. The number of lines is given by the user.
# ```python
# *
# **
# ***
# ****
# *****
# ```
#
# # Exercise 3
# Create a Python program that prints a staircase of numbers as shown below. The number of lines is given by the user.
# ```python
# 1
# 222
# 33333
# 4444444
# 555555555
# ```
#
# # Exercise 4
# Create a Python program that prints an inverted staircase of numbers as shown below. The number of lines is given by the user.
# ```python
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1
# ```
#
# # Exercise 5
# Create a Python program that prints a staircase of asterisks as shown below. The number of lines is given by the user.
# ```python
# *
# ***
# *****
# *******
# *********
# ```
#
# # Exercise 6
# Create a Python program that draws a solid pyramid of asterisks. The height of the pyramid is entered by the user. An example output for a pyramid of height 5 is:
# ```python
#         *
#       ***
#     *****
#   *******
# *********
# ```
#
# # Exercise 7
# Create a Python program that prints a staircase of asterisks as shown below. The number of lines is given by the user.
# ```python
#     *
#    ***
#   *****
#  *******
# *********
# ```
#
# # Exercise 8
# Create a Python program that prints an inverted pyramid of asterisks as shown below. The maximum number of asterisks in the longest line is given by the user; in this example, it is 5.
# ```python
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
# ```
#
# # Exercise 9
# Create a Python program that prints a staircase of numbers as shown below. The number of lines is given by the user.
# ```python
#     1
#    212
#   32123
#  4321234
# 543212345
# ```
#
# # Exercise 10
# Create a Python program that prints a staircase of numbers as shown below. The number of lines is given by the user.
# ```python
# 1
# 3 1
# 5 3 1
# 7 5 3 1
# 9 7 5 3 1
# ```
