# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1
#
# Given two strings, return a set with the letters that are in both.
#
# For example, if the input strings are `"hello"` and `"world"`, the output should be `{'l', 'o'}` (the letters that appear in both strings).

# %% [markdown]
# ## Exercise 2
#
# With the intention of better organizing internships (FCT), create several sets, one for each programming language you know, and add to each one the students who can program in that language.
#
# A job offer has just arrived that requires candidates to can program in Java, C# and Python. Which students could apply for it?
#
# For example:
#
# If the students who can program in each language are as follows:
# - Python: Alice, Bob, Charlie, Diana, John
# - Java: Alice, Charlie, Eve, John
# - C#: Alice, Bob, John, Frank
#
# The students who could apply for the job offer would be Alice and John.
